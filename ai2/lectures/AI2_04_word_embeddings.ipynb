# %% [markdown]
# <h1>CS4619: Artificial Intelligence II</h1>
# <h1>Word Embeddings</h1>
# <h2>
#     Derek Bridge<br>
#     School of Computer Science and Information Technology<br>
#     University College Cork
# </h2>

# %% [markdown]
# <h1>Initialization</h1>
# $\newcommand{\Set}[1]{\{#1\}}$
# $\newcommand{\Tuple}[1]{\langle#1\rangle}$
# $\newcommand{\v}[1]{\pmb{#1}}$
# $\newcommand{\cv}[1]{\begin{bmatrix}#1\end{bmatrix}}$
# $\newcommand{\rv}[1]{[#1]}$
# $\DeclareMathOperator{\argmax}{arg\,max}$
# $\DeclareMathOperator{\argmin}{arg\,min}$
# $\DeclareMathOperator{\dist}{dist}$
# $\DeclareMathOperator{\abs}{abs}$

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Embedding

from tensorflow.keras.optimizers import SGD

from tensorflow.keras.callbacks import EarlyStopping

# %%
# This OneHot layer comes from https://fdalvi.github.io/blog/2018-04-07-keras-sequential-onehot/

from tensorflow.keras.layers import Lambda
from tensorflow.keras import backend as K

def OneHot(input_dim=None, input_length=None):
    # Check if inputs were supplied correctly
    if input_dim is None or input_length is None:
        raise TypeError("input_dim or input_length is not set")

    # Helper method (not inlined for clarity)
    def _one_hot(x, num_classes):
        return K.one_hot(K.cast(x, 'uint8'),
                          num_classes=num_classes)

    # Final layer representation as a Lambda layer
    return Lambda(_one_hot,
                  arguments={'num_classes': input_dim},
                  input_shape=(input_length,))

# %% [markdown]
# <h1>Acknowledgements</h1>
# <ul>
#     <li>The image captioning example comes from a talk by Jeff Dean of Google at
#         <i>AI Frontiers: Trends and Developments in Deep Learning Research</i>:
#         <a href="https://www.slideshare.net/AIFrontiers/jeff-dean-trends-and-developments-in-deep-learning-research">https://www.slideshare.net/AIFrontiers/jeff-dean-trends-and-developments-in-deep-learning-research</a>
#     </li>
#     <li>Part of the code comes from chapter 6 of:
#         Fran&ccedil;ois Chollet: <i>Deep Learning with Python</i>,
#         Manning Publications, 2018
#     </li>
# </ul>

# %% [markdown]
# <h1>Nautral Language Processing</h1>
# <ul>
#     <li>In the previous lecture, we represented each document as a single vector (bag-of-words).
#         <ul>
#             <li>This is OK for some applications, e.g. spam filtering.</li>
#         </ul>
#     </li>
#     <li>But for many applications of natural language processing (NLP), we may need to treat documents as
#         <em>sequences</em> (lists) of words (and maybe of punctuation symbols also):
#         <ul>
#             <li>Sentiment analysis, e.g. of movie reviews or tweets;</li>
#             <li>Machine translation;</li>
#             <li>Image captioning
#                 <figure>
#                     <img src="images/image_captioning.jpg" />
#                 </figure>
#             </li>
#             <li>Question-answering and chatbots.</li>
#         </ul>
#     </li>
#     <li>There are other applications where each example is a sequence of features too, e.g.:
#         <ul>
#             <li>processing speech;</li>
#             <li>processing genomic data;</li>
#             <li>timeseries prediction;</li>
#             <li>clickstream prediction</li>
#         </ul>
#     </li>
# </ul>

# %% [markdown]
# <h2>Sequences of integers</h2>
# <ul>
#     <li>Now, each word will be given a unique integer (an index, e.g. "the" might be word number 2).
#     </li>
#     <li>A document will be a sequence of these integers.
#         <ul>
#             <li>We may add special symbols to the start and end of the document, also given an index.</li>
#         </ul>
#     </li>
#     <li>If we have a batch of documents, we may prefer them all to be the same length (e.g. <i>maxlen</i> = 100 words).
#         In which case, we will need to:
#         <ul>
#             <li>truncate documents that are longer than 100 words; and</li>
#             <li>pad documents that have fewer than 100 words.</li>
#         </ul>
#     </li>
# </ul>

# %% [markdown]
# <h2>IMDB Reviews, Again</h2>
# <ul>
#     <li>Let's read in our small IMDB reviews dataset again and turn it into sequences of integers.</li>
# </ul>

# %%
df = pd.read_csv("../datasets/dataset_5000_reviews.csv")

# %%
# Dataset size
m = len(df)

# We'll keep only the 1000 most common words in the reviews.
vocab_size = 1000

# We'll truncate/pad so that each review has 100 words
maxlen = 200

# %%
tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(df["review"])
sequences = tokenizer.texts_to_sequences(df["review"])
padded_sequences = pad_sequences(sequences, maxlen=maxlen)

# %%
# Let's look at the first review
padded_sequences[0]
# Out:
# array([  1,  81, 152,  12,  70,  40,  13,  98,   3, 137,   4, 563,  58,
#        273,   8, 203,  35,   1, 554, 135,  70,  11,   6,  22,   2, 123,
#         17,   1,  38,  11, 123,  54,  16,   5, 409,  38, 563,  98,   6,
#          8,   1, 367, 350,   4,   1, 554,   7,   7,   9,   6, 423,  14,
#         12,   6,   1, 346,   5,   1,   9,  20, 558,  32,   4,   1, 117,
#         30,   1,  25,   3, 387,  34,   6,  22, 283,  20,   1, 558,   6,
#        330,   5, 111,   3,  52,  34, 357,   3,  23, 105, 233, 241,   7,
#          7,  10,  56, 129,   1, 281,   4,   1, 123,   6, 664,   5,   1,
#        196,  12,   9, 261, 117,  82, 280, 610, 791, 174,  17, 791, 791,
#        782, 148, 943, 179,   1,  81, 421,  10, 122, 221,  70,  14,  34,
#          9,  13,  10, 424, 129,  10,  13,  17,   9,  18,  14,  10, 274,
#         52,  10,   2,  17,   3, 186,   5,   1, 283,   4, 563,  22,  39,
#        563,  18,  26,  43,  17,   2, 536,  20, 627,   3,  76, 241,  16,
#          9,  67, 665, 731, 103, 683,  78, 664,   5,  63, 509,   4, 972,
#         38, 552, 144,  21, 198, 438,  16,  46,   6, 724,  42,  21,  68,
#         76,   8,  16, 118, 528], dtype=int32)

# %%
# Let's look at how the indexes relate to words
tokenizer.word_index
# Out:
# {'the': 1,
#  'a': 2,
#  'and': 3,
#  'of': 4,
#  'to': 5,
#  'is': 6,
#  'br': 7,
#  'in': 8,
#  'it': 9,
#  'i': 10,
#  'this': 11,
#  'that': 12,
#  'was': 13,
#  'as': 14,
#  'movie': 15,
#  'with': 16,
#  'for': 17,
#  'but': 18,
#  'film': 19,
#  'on': 20,
#  'you': 21,
#  'not': 22,
#  'are': 23,
#  'his': 24,
#  'have': 25,
#  'be': 26,
#  'one': 27,
#  'he': 28,
#  'at': 29,
#  'all': 30,
#  'by': 31,
#  'an': 32,
#  'they': 33,
#  'so': 34,
#  'from': 35,
#  'who': 36,
#  'like': 37,
#  'or': 38,
#  'just': 39,
#  'about': 40,
#  'her': 41,
#  'if': 42,
#  'out': 43,
#  "it's": 44,
#  'has': 45,
#  'what': 46,
#  'there': 47,
#  'some': 48,
#  'good': 49,
#  'when': 50,
#  'very': 51,
#  'more': 52,
#  'up': 53,
#  'no': 54,
#  'even': 55,
#  'would': 56,
#  'time': 57,
#  'which': 58,
#  'my': 59,
#  'she': 60,
#  'story': 61,
#  'see': 62,
#  'their': 63,
#  'really': 64,
#  'only': 65,
#  'had': 66,
#  'well': 67,
#  'can': 68,
#  'were': 69,
#  'me': 70,
#  'much': 71,
#  'been': 72,
#  'than': 73,
#  'because': 74,
#  'we': 75,
#  'get': 76,
#  'bad': 77,
#  'into': 78,
#  'do': 79,
#  'will': 80,
#  'first': 81,
#  'other': 82,
#  'also': 83,
#  'people': 84,
#  'great': 85,
#  'how': 86,
#  'most': 87,
#  'him': 88,
#  "don't": 89,
#  'way': 90,
#  'made': 91,
#  'make': 92,
#  'them': 93,
#  'then': 94,
#  'movies': 95,
#  'too': 96,
#  'any': 97,
#  'its': 98,
#  'after': 99,
#  'could': 100,
#  'watch': 101,
#  'characters': 102,
#  'being': 103,
#  'think': 104,
#  'never': 105,
#  'films': 106,
#  'character': 107,
#  'plot': 108,
#  'little': 109,
#  'seen': 110,
#  'many': 111,
#  'two': 112,
#  'acting': 113,
#  'life': 114,
#  'best': 115,
#  'know': 116,
#  'where': 117,
#  'your': 118,
#  'off': 119,
#  'love': 120,
#  'did': 121,
#  'ever': 122,
#  'show': 123,
#  'over': 124,
#  'does': 125,
#  'scene': 126,
#  'better': 127,
#  'still': 128,
#  'say': 129,
#  'here': 130,
#  'while': 131,
#  'man': 132,
#  'these': 133,
#  'something': 134,
#  'go': 135,
#  'end': 136,
#  'scenes': 137,
#  'why': 138,
#  'real': 139,
#  'through': 140,
#  'such': 141,
#  'should': 142,
#  'back': 143,
#  'watching': 144,
#  'before': 145,
#  "i'm": 146,
#  'now': 147,
#  "doesn't": 148,
#  'though': 149,
#  'actors': 150,
#  'those': 151,
#  'thing': 152,
#  'work': 153,
#  '10': 154,
#  'going': 155,
#  'new': 156,
#  'old': 157,
#  'years': 158,
#  'look': 159,
#  'funny': 160,
#  'nothing': 161,
#  "didn't": 162,
#  'makes': 163,
#  'actually': 164,
#  'lot': 165,
#  'another': 166,
#  'director': 167,
#  'same': 168,
#  'again': 169,
#  'few': 170,
#  'every': 171,
#  'find': 172,
#  'us': 173,
#  'pretty': 174,
#  'part': 175,
#  'down': 176,
#  'horror': 177,
#  'want': 178,
#  'around': 179,
#  'quite': 180,
#  'things': 181,
#  'enough': 182,
#  "can't": 183,
#  'young': 184,
#  'big': 185,
#  'got': 186,
#  'both': 187,
#  'however': 188,
#  'must': 189,
#  'world': 190,
#  'long': 191,
#  'cast': 192,
#  'take': 193,
#  'seems': 194,
#  'thought': 195,
#  'fact': 196,
#  'come': 197,
#  'may': 198,
#  'least': 199,
#  'without': 200,
#  'almost': 201,
#  'gets': 202,
#  'right': 203,
#  "that's": 204,
#  'always': 205,
#  'own': 206,
#  'give': 207,
#  'anything': 208,
#  "i've": 209,
#  'original': 210,
#  'might': 211,
#  'comedy': 212,
#  'whole': 213,
#  'family': 214,
#  'action': 215,
#  'done': 216,
#  'between': 217,
#  "isn't": 218,
#  'point': 219,
#  'series': 220,
#  'saw': 221,
#  'feel': 222,
#  'script': 223,
#  'times': 224,
#  'minutes': 225,
#  'making': 226,
#  'role': 227,
#  'interesting': 228,
#  'since': 229,
#  'bit': 230,
#  "there's": 231,
#  'probably': 232,
#  'far': 233,
#  'performance': 234,
#  'tv': 235,
#  'am': 236,
#  'yet': 237,
#  'music': 238,
#  'guy': 239,
#  'last': 240,
#  'away': 241,
#  'girl': 242,
#  '2': 243,
#  'played': 244,
#  'rather': 245,
#  'woman': 246,
#  "he's": 247,
#  'anyone': 248,
#  'day': 249,
#  'although': 250,
#  'having': 251,
#  'worst': 252,
#  'each': 253,
#  'hard': 254,
#  'our': 255,
#  'screen': 256,
#  'comes': 257,
#  'fun': 258,
#  'kind': 259,
#  'found': 260,
#  'goes': 261,
#  'american': 262,
#  'sure': 263,
#  'book': 264,
#  'dvd': 265,
#  'three': 266,
#  'everything': 267,
#  'especially': 268,
#  'looks': 269,
#  'course': 270,
#  'looking': 271,
#  'takes': 272,
#  'set': 273,
#  'watched': 274,
#  'put': 275,
#  'trying': 276,
#  'maybe': 277,
#  'ending': 278,
#  'effects': 279,
#  'shows': 280,
#  'main': 281,
#  'believe': 282,
#  'high': 283,
#  'idea': 284,
#  'once': 285,
#  'true': 286,
#  'audience': 287,
#  'money': 288,
#  'place': 289,
#  'john': 290,
#  'night': 291,
#  'reason': 292,
#  'someone': 293,
#  'job': 294,
#  'play': 295,
#  'sense': 296,
#  'different': 297,
#  'said': 298,
#  "wasn't": 299,
#  'worth': 300,
#  'actor': 301,
#  'special': 302,
#  'instead': 303,
#  'war': 304,
#  'himself': 305,
#  'shot': 306,
#  'house': 307,
#  'beautiful': 308,
#  'mind': 309,
#  'left': 310,
#  'together': 311,
#  'during': 312,
#  'year': 313,
#  'excellent': 314,
#  'star': 315,
#  'simply': 316,
#  'seem': 317,
#  'plays': 318,
#  '1': 319,
#  'second': 320,
#  'along': 321,
#  'version': 322,
#  'completely': 323,
#  'read': 324,
#  'line': 325,
#  'poor': 326,
#  'used': 327,
#  'half': 328,
#  '3': 329,
#  'home': 330,
#  'budget': 331,
#  'help': 332,
#  'else': 333,
#  'everyone': 334,
#  'nice': 335,
#  'seeing': 336,
#  'fan': 337,
#  'short': 338,
#  'stupid': 339,
#  "you're": 340,
#  'awful': 341,
#  'boring': 342,
#  'less': 343,
#  'men': 344,
#  'father': 345,
#  'given': 346,
#  'need': 347,
#  'kids': 348,
#  'production': 349,
#  'use': 350,
#  'performances': 351,
#  'hollywood': 352,
#  'black': 353,
#  'camera': 354,
#  'later': 355,
#  'tell': 356,
#  'death': 357,
#  'try': 358,
#  'until': 359,
#  'wife': 360,
#  'top': 361,
#  'video': 362,
#  'next': 363,
#  'low': 364,
#  'wonderful': 365,
#  'recommend': 366,
#  'classic': 367,
#  'dead': 368,
#  'rest': 369,
#  'absolutely': 370,
#  'piece': 371,
#  'human': 372,
#  'small': 373,
#  'either': 374,
#  'school': 375,
#  'terrible': 376,
#  'name': 377,
#  'full': 378,
#  'women': 379,
#  'remember': 380,
#  'understand': 381,
#  'truly': 382,
#  'couple': 383,
#  'based': 384,
#  'game': 385,
#  'getting': 386,
#  'face': 387,
#  'wrong': 388,
#  'often': 389,
#  'mean': 390,
#  'enjoy': 391,
#  'mother': 392,
#  'came': 393,
#  'keep': 394,
#  'worse': 395,
#  'doing': 396,
#  'person': 397,
#  'others': 398,
#  'finally': 399,
#  'let': 400,
#  'playing': 401,
#  'stars': 402,
#  'itself': 403,
#  'friends': 404,
#  'written': 405,
#  'perhaps': 406,
#  'title': 407,
#  'dialogue': 408,
#  'sex': 409,
#  'evil': 410,
#  'start': 411,
#  'lost': 412,
#  'perfect': 413,
#  'gives': 414,
#  'totally': 415,
#  'waste': 416,
#  'early': 417,
#  'moments': 418,
#  "you'll": 419,
#  'oh': 420,
#  'episode': 421,
#  'laugh': 422,
#  'called': 423,
#  "couldn't": 424,
#  'yes': 425,
#  'entire': 426,
#  'several': 427,
#  "she's": 428,
#  'case': 429,
#  'style': 430,
#  'days': 431,
#  'head': 432,
#  'liked': 433,
#  'under': 434,
#  'loved': 435,
#  'supposed': 436,
#  'definitely': 437,
#  'become': 438,
#  'picture': 439,
#  'lines': 440,
#  'overall': 441,
#  'sort': 442,
#  '5': 443,
#  'friend': 444,
#  'god': 445,
#  'despite': 446,
#  'beginning': 447,
#  'direction': 448,
#  'able': 449,
#  'went': 450,
#  'guys': 451,
#  'entertaining': 452,
#  'fans': 453,
#  'boy': 454,
#  'humor': 455,
#  'drama': 456,
#  'felt': 457,
#  'wants': 458,
#  'certainly': 459,
#  'hope': 460,
#  'sound': 461,
#  'already': 462,
#  '4': 463,
#  'throughout': 464,
#  'history': 465,
#  'killer': 466,
#  'children': 467,
#  'cinema': 468,
#  'mr': 469,
#  '\x96': 470,
#  "i'd": 471,
#  'white': 472,
#  'stuff': 473,
#  'b': 474,
#  'dark': 475,
#  'turn': 476,
#  'soon': 477,
#  'lives': 478,
#  'heart': 479,
#  'writing': 480,
#  'problem': 481,
#  'final': 482,
#  'seemed': 483,
#  'becomes': 484,
#  'past': 485,
#  'quality': 486,
#  'care': 487,
#  'town': 488,
#  'fine': 489,
#  'matter': 490,
#  'favorite': 491,
#  'live': 492,
#  'brilliant': 493,
#  'wanted': 494,
#  'coming': 495,
#  'works': 496,
#  'against': 497,
#  'stop': 498,
#  'lead': 499,
#  'example': 500,
#  'thinking': 501,
#  'behind': 502,
#  'son': 503,
#  'slow': 504,
#  'type': 505,
#  'parts': 506,
#  'run': 507,
#  'art': 508,
#  'lack': 509,
#  'enjoyed': 510,
#  "they're": 511,
#  'themselves': 512,
#  'eyes': 513,
#  'gave': 514,
#  'girls': 515,
#  'extremely': 516,
#  'tries': 517,
#  'flick': 518,
#  'michael': 519,
#  'known': 520,
#  'act': 521,
#  'amazing': 522,
#  'unfortunately': 523,
#  'turns': 524,
#  'hour': 525,
#  'late': 526,
#  'horrible': 527,
#  'side': 528,
#  'leave': 529,
#  'guess': 530,
#  'english': 531,
#  'fight': 532,
#  'save': 533,
#  'actress': 534,
#  'close': 535,
#  'kill': 536,
#  'sometimes': 537,
#  'myself': 538,
#  'murder': 539,
#  'etc': 540,
#  'viewer': 541,
#  'killed': 542,
#  'feeling': 543,
#  'involved': 544,
#  'age': 545,
#  'highly': 546,
#  'directed': 547,
#  'child': 548,
#  'police': 549,
#  'attempt': 550,
#  'group': 551,
#  'experience': 552,
#  'expect': 553,
#  'word': 554,
#  'except': 555,
#  'car': 556,
#  's': 557,
#  'city': 558,
#  'seriously': 559,
#  'complete': 560,
#  'told': 561,
#  'obviously': 562,
#  'violence': 563,
#  'hand': 564,
#  'cut': 565,
#  'heard': 566,
#  'decent': 567,
#  'took': 568,
#  'hell': 569,
#  'genre': 570,
#  'upon': 571,
#  'robert': 572,
#  'gore': 573,
#  'roles': 574,
#  'possible': 575,
#  'looked': 576,
#  'relationship': 577,
#  "won't": 578,
#  'happens': 579,
#  'number': 580,
#  'cool': 581,
#  'serious': 582,
#  'cannot': 583,
#  'reality': 584,
#  'self': 585,
#  'view': 586,
#  'interest': 587,
#  'chance': 588,
#  'opening': 589,
#  'happen': 590,
#  'writer': 591,
#  'voice': 592,
#  'shown': 593,
#  'moment': 594,
#  'body': 595,
#  'kid': 596,
#  'usual': 597,
#  'starts': 598,
#  'daughter': 599,
#  'huge': 600,
#  'saying': 601,
#  'ridiculous': 602,
#  'brother': 603,
#  'annoying': 604,
#  'talent': 605,
#  'david': 606,
#  'released': 607,
#  'simple': 608,
#  'across': 609,
#  "wouldn't": 610,
#  'anyway': 611,
#  'stories': 612,
#  'obvious': 613,
#  'rock': 614,
#  'score': 615,
#  'ago': 616,
#  'major': 617,
#  'problems': 618,
#  'says': 619,
#  'bring': 620,
#  'british': 621,
#  'particularly': 622,
#  'ok': 623,
#  'yourself': 624,
#  'usually': 625,
#  'hilarious': 626,
#  'order': 627,
#  'documentary': 628,
#  'blood': 629,
#  'hit': 630,
#  "i'll": 631,
#  'alone': 632,
#  'television': 633,
#  'including': 634,
#  'song': 635,
#  'started': 636,
#  'living': 637,
#  'silly': 638,
#  'hero': 639,
#  'important': 640,
#  'strong': 641,
#  'disappointed': 642,
#  'hours': 643,
#  'rating': 644,
#  'ends': 645,
#  'happy': 646,
#  'level': 647,
#  'none': 648,
#  'exactly': 649,
#  'basically': 650,
#  'today': 651,
#  'cinematography': 652,
#  'james': 653,
#  'wonder': 654,
#  'husband': 655,
#  'call': 656,
#  'jokes': 657,
#  'words': 658,
#  'running': 659,
#  'dull': 660,
#  'non': 661,
#  'power': 662,
#  'beyond': 663,
#  'due': 664,
#  'middle': 665,
#  "film's": 666,
#  'whose': 667,
#  'ones': 668,
#  'moving': 669,
#  'miss': 670,
#  'taken': 671,
#  'cheap': 672,
#  'lots': 673,
#  'novel': 674,
#  'apparently': 675,
#  'mostly': 676,
#  'sad': 677,
#  'clear': 678,
#  'review': 679,
#  'career': 680,
#  'four': 681,
#  'space': 682,
#  'turned': 683,
#  'thriller': 684,
#  'country': 685,
#  'scary': 686,
#  'knows': 687,
#  'taking': 688,
#  'local': 689,
#  'enjoyable': 690,
#  'team': 691,
#  'light': 692,
#  'die': 693,
#  'happened': 694,
#  'monster': 695,
#  'message': 696,
#  "aren't": 697,
#  'comic': 698,
#  'sets': 699,
#  'shots': 700,
#  'surprise': 701,
#  '8': 702,
#  'please': 703,
#  'wish': 704,
#  "haven't": 705,
#  'events': 706,
#  'mystery': 707,
#  'modern': 708,
#  'soundtrack': 709,
#  'bunch': 710,
#  'add': 711,
#  "'": 712,
#  'female': 713,
#  'animation': 714,
#  'feels': 715,
#  'working': 716,
#  'talking': 717,
#  'above': 718,
#  'episodes': 719,
#  'sequence': 720,
#  'suspense': 721,
#  'tells': 722,
#  'attention': 723,
#  'viewing': 724,
#  'subject': 725,
#  'opinion': 726,
#  'king': 727,
#  'single': 728,
#  'musical': 729,
#  'crap': 730,
#  'class': 731,
#  'editing': 732,
#  'comments': 733,
#  'songs': 734,
#  'talk': 735,
#  'actual': 736,
#  'clearly': 737,
#  'learn': 738,
#  'easy': 739,
#  'doubt': 740,
#  '7': 741,
#  'romantic': 742,
#  'predictable': 743,
#  'dance': 744,
#  'rent': 745,
#  'room': 746,
#  'filmed': 747,
#  "what's": 748,
#  'tried': 749,
#  'knew': 750,
#  'sorry': 751,
#  'change': 752,
#  'george': 753,
#  'ten': 754,
#  'sequences': 755,
#  'somewhat': 756,
#  'buy': 757,
#  'eye': 758,
#  'needs': 759,
#  'figure': 760,
#  'five': 761,
#  'deal': 762,
#  'expected': 763,
#  'believable': 764,
#  'storyline': 765,
#  'island': 766,
#  'appears': 767,
#  'fast': 768,
#  'entertainment': 769,
#  'form': 770,
#  "you've": 771,
#  'greatest': 772,
#  'decided': 773,
#  'finds': 774,
#  'lame': 775,
#  'whether': 776,
#  'french': 777,
#  'brought': 778,
#  'earth': 779,
#  'named': 780,
#  'crew': 781,
#  'romance': 782,
#  'jack': 783,
#  'famous': 784,
#  'sister': 785,
#  'typical': 786,
#  'falls': 787,
#  'crime': 788,
#  'among': 789,
#  'truth': 790,
#  'forget': 791,
#  'killing': 792,
#  '20': 793,
#  'future': 794,
#  'elements': 795,
#  'realistic': 796,
#  'meet': 797,
#  'giving': 798,
#  'fantastic': 799,
#  'using': 800,
#  'surprised': 801,
#  'tom': 802,
#  'directing': 803,
#  'wait': 804,
#  'straight': 805,
#  'supporting': 806,
#  'nearly': 807,
#  'lady': 808,
#  'means': 809,
#  'release': 810,
#  'dialog': 811,
#  'easily': 812,
#  'parents': 813,
#  'stay': 814,
#  'mention': 815,
#  'avoid': 816,
#  'imdb': 817,
#  'hate': 818,
#  'average': 819,
#  'points': 820,
#  'effort': 821,
#  'gone': 822,
#  'shame': 823,
#  'open': 824,
#  'strange': 825,
#  'reviews': 826,
#  'near': 827,
#  'theme': 828,
#  'paul': 829,
#  'screenplay': 830,
#  're': 831,
#  'sequel': 832,
#  'showing': 833,
#  'theater': 834,
#  'minute': 835,
#  'towards': 836,
#  'fall': 837,
#  'otherwise': 838,
#  'period': 839,
#  'begins': 840,
#  'within': 841,
#  'deep': 842,
#  'begin': 843,
#  'check': 844,
#  'sci': 845,
#  'fi': 846,
#  'herself': 847,
#  'total': 848,
#  'japanese': 849,
#  'box': 850,
#  'stand': 851,
#  'indeed': 852,
#  'hot': 853,
#  'kept': 854,
#  'follow': 855,
#  'list': 856,
#  'particular': 857,
#  'material': 858,
#  'features': 859,
#  'plus': 860,
#  'dr': 861,
#  'certain': 862,
#  'worked': 863,
#  'memorable': 864,
#  'premise': 865,
#  'sit': 866,
#  'realize': 867,
#  'laughs': 868,
#  'needed': 869,
#  'whom': 870,
#  'question': 871,
#  'doctor': 872,
#  'earlier': 873,
#  'meets': 874,
#  'weak': 875,
#  'disney': 876,
#  'effect': 877,
#  'atmosphere': 878,
#  'plain': 879,
#  'rich': 880,
#  'development': 881,
#  'leads': 882,
#  'situation': 883,
#  'feature': 884,
#  'footage': 885,
#  'forward': 886,
#  'various': 887,
#  'okay': 888,
#  'difficult': 889,
#  'peter': 890,
#  'boys': 891,
#  'viewers': 892,
#  'similar': 893,
#  'business': 894,
#  'dog': 895,
#  't': 896,
#  'water': 897,
#  'hear': 898,
#  'perfectly': 899,
#  'acted': 900,
#  'richard': 901,
#  'general': 902,
#  'whatever': 903,
#  'mark': 904,
#  'move': 905,
#  'nor': 906,
#  'stage': 907,
#  'quickly': 908,
#  'd': 909,
#  'fire': 910,
#  'tale': 911,
#  "let's": 912,
#  'missing': 913,
#  'portrayed': 914,
#  'somehow': 915,
#  'reasons': 916,
#  'credits': 917,
#  "who's": 918,
#  'cute': 919,
#  'note': 920,
#  'setting': 921,
#  'york': 922,
#  'crazy': 923,
#  'directors': 924,
#  'america': 925,
#  'free': 926,
#  'de': 927,
#  'eventually': 928,
#  'imagine': 929,
#  'ways': 930,
#  'e': 931,
#  'powerful': 932,
#  'success': 933,
#  'season': 934,
#  'sexual': 935,
#  'dramatic': 936,
#  'alien': 937,
#  'leading': 938,
#  '9': 939,
#  'possibly': 940,
#  'laughing': 941,
#  'result': 942,
#  'mess': 943,
#  'era': 944,
#  'dumb': 945,
#  'battle': 946,
#  'casting': 947,
#  'personal': 948,
#  'pure': 949,
#  'drug': 950,
#  'brings': 951,
#  'appear': 952,
#  'masterpiece': 953,
#  'hands': 954,
#  'girlfriend': 955,
#  'became': 956,
#  'air': 957,
#  'poorly': 958,
#  'hold': 959,
#  'leaves': 960,
#  'mentioned': 961,
#  'cheesy': 962,
#  'wasted': 963,
#  'gun': 964,
#  '15': 965,
#  'fails': 966,
#  'apart': 967,
#  'company': 968,
#  'following': 969,
#  'creepy': 970,
#  'party': 971,
#  'street': 972,
#  'caught': 973,
#  'married': 974,
#  'incredibly': 975,
#  'produced': 976,
#  'talented': 977,
#  'secret': 978,
#  'match': 979,
#  'baby': 980,
#  'oscar': 981,
#  'sounds': 982,
#  'weird': 983,
#  'reading': 984,
#  'fairly': 985,
#  'previous': 986,
#  'write': 987,
#  'attempts': 988,
#  'unless': 989,
#  'u': 990,
#  'forced': 991,
#  'red': 992,
#  'admit': 993,
#  'fantasy': 994,
#  'older': 995,
#  'emotional': 996,
#  'large': 997,
#  'changed': 998,
#  'third': 999,
#  'expecting': 1000,
#  ...}

# %%
# Train/test split
split_point = int(m * 0.8)
rest_of_X = padded_sequences[:split_point]
test_X = padded_sequences[split_point:] 

# Target values, encoded and converted to a 1D numpy array
label_encoder = LabelEncoder()
label_encoder.fit(df["sentiment"])
rest_of_y = label_encoder.transform(df["sentiment"][:split_point])
test_y = label_encoder.transform(df["sentiment"][split_point:])

# %% [markdown]
# <h1>One-Hot Encoding</h1>
# <ul>
#     <li>We cannot use the indexes directly. Why not?</li>
#     <li>So we could one-hot encode each word.</li>
#
# </ul>

# %% [markdown]
# <h2>IMDB</h2>
# <ul>
#     <li>In our IMDB example, each review will now be represented by a list (of length 100) of binary-valued
#         vectors (where
#         the dimenion of the vector is 1000. Why?)
#     </li>
#     <li>Converting from integer indexes to binary vectors can be done in many ways. We will do it using a layer
#         in our network using some code given earlier.
#     </li>
#     <li>Then we will flatten the input into a single vector (<code>maxlen * vocab_size</code>) and then use
#         a few dense layers.
#     </li>
# </ul>

# %%
def build_one_hot_network(): 
    network = Sequential()
    network.add(OneHot(input_dim=vocab_size, input_length=maxlen))
    network.add(Flatten())
    network.add(Dense(32, activation="relu"))
    network.add(Dense(1, activation="sigmoid"))
    network.compile(optimizer=SGD(lr=0.001), loss="binary_crossentropy", metrics=["acc"])
    return network

# %%
one_hot_network = build_one_hot_network()

# %%
one_hot_network.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_4 (Lambda)            (None, 200, 1000)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 200000)            0
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                6400032
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 6,400,065
# Trainable params: 6,400,065
# Non-trainable params: 0
# _________________________________________________________________

# %%
one_hot_history = one_hot_network.fit(rest_of_X, rest_of_y, epochs=10, batch_size=32, validation_split=0.25, 
                                      callbacks=[EarlyStopping(monitor="val_loss", patience=2)], verbose=0)

# %%
pd.DataFrame(one_hot_history.history).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <ul>
#     <li>Not great results but not surprising:
#         <ul>
#             <li>Small dataset</li>
#             <li>One-hot encoding is a poor choice.</li>
#         </ul>
#     </li>
# <ul>

# %%
# An illustration of why  one-hot encoding is not great.

def cosine_similarity(x, xprime):
    # Assumes x and  xprime are already normalized
    # Converts from sparse matrices because np.dot does not work on them
    return x.dot(xprime.T)

# Word indexes
print("like: ", tokenizer.word_index["like"] )
print("love: ", tokenizer.word_index["love"] )
print("hate: ", tokenizer.word_index["hate"] )

# One hot encodings
one_hot_like = np.zeros(vocab_size)
one_hot_like[ tokenizer.word_index["like"] ] = 1

one_hot_love = np.zeros(vocab_size)
one_hot_love[ tokenizer.word_index["love"] ] = 1

one_hot_hate = np.zeros(vocab_size)
one_hot_hate[ tokenizer.word_index["love"] ] = 1

# Similarities
print("like and love: ", one_hot_like.dot(one_hot_love) )
print("like and hate: ", one_hot_like.dot(one_hot_hate) )
# Out:
# like:  37
# love:  120
# hate:  818
# like and love:  0.0
# like and hate:  0.0

# %% [markdown]
# <h1>Word Embeddings</h1>
# <ul>
#     <li>One-hot encoding uses large, sparse vectors.</li>
#     <li><b>Word embeddings</b> are small, non-sparse vectors, e.g. the dimension might be 100 or 200.</li>
#     <li>To illustrate the ideas, we will use vectors of size 2 (so we can draw 2D diagrams).</li>
#     <li>Perhaps we will have the following word embeddings:
#         <img src="images/embeddings.png" style="float: right; margin-left: 5em" />
#         <ul>
#             <li>Dog: $\langle 0.4, 0.3\rangle$</li>
#             <li>Hound: $\langle 0.38, 0.32\rangle$</li>
#             <li>Wolf: $\langle 0.4, 0.8\rangle$</li>
#             <li>Cat: $\langle 0.75, 0.2\rangle$</li>
#             <li>Tiger: $\langle 0.75, 0.7$</li>
#         </ul>
#     </li>
#     <li>The word embeddings we choose should reflect semantic relationships between the words:
#         <ul>
#             <li>Words with similar meanings should be close together (as with Dog and Hound) and in general
#                 the distance between embeddings should reflect how closely related the meanings are.
#             </li>
#             <li>Geometric transformations might encode semantic relationships, e.g.:
#                 <ul>
#                     <li>Adding $\langle 0, 0.5\rangle$ to the word embedding for Dog gives us the word embedding
#                         for Wolf; adding the same vector to the embedding for Cat gives the embedding for Tiger;
#                         $\langle 0, 0.5\rangle$ is the "from pet to wild animal" transformation.
#                     </li>
#                     <li>Similarly $\langle 0.35, -0.1\rangle$ is the "from canine to feline" transformation. Why?
#                     </li>
#                 </ul>
#             </li>
#         </ul>
#     </li>
# </ul>

# %% [markdown]
# <h2>Learning word embeddings</h2>
# <ul>
#     <li>We learn the word embeddings from the dataset of documents.
#     </li>
#     <li>Conceptually,
#         <ul>
#             <li>The values in the vectors are initialized randomly;</li>
#             <li>Then they are adjusted during learning.</li>
#         </ul>
#     </li>
#     <li>But Keras does it using a network layer:
#         <ul>
#             <li>During learning, the weights of the layer are adjusted.</li>
#             <li>The activations of the units in the layer are the word embeddings.</li>
#         </ul>
#     </li>
# </ul>

# %% [markdown]
# <h2>IMDB</h2>

# %%
# Throughout the code, we will use 100-dimensional word embeddings (including the pretrained GloVe embeddings later)

embedding_dimension = 100

# %%
def build_word_embedding_network(): 
    network = Sequential()
    network.add(Embedding(input_dim=vocab_size, input_length=maxlen, output_dim=embedding_dimension))
    network.add(Flatten())
    network.add(Dense(32, activation="relu"))
    network.add(Dense(1, activation="sigmoid"))
    network.compile(optimizer=SGD(lr=0.001), loss="binary_crossentropy", metrics=["acc"])
    return network

# %%
word_embedding_network = build_word_embedding_network()

# %%
word_embedding_network.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 200, 100)          100000
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 20000)             0
# _________________________________________________________________
# dense_14 (Dense)             (None, 32)                640032
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 740,065
# Trainable params: 740,065
# Non-trainable params: 0
# _________________________________________________________________

# %%
word_embedding_history = word_embedding_network.fit(rest_of_X, rest_of_y, epochs=10, batch_size=32, validation_split=0.25, 
                                      callbacks=[EarlyStopping(monitor="val_loss", patience=2)], verbose=0)

# %%
pd.DataFrame(word_embedding_history.history).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <ul>
#     <li>Possibly worse in this case! Perhaps because so little training data.</li>
# </ul>

# %% [markdown]
# <h2>Pretrained Word Embeddings</h2>
# <ul>
#     <li>Above, we got our neural network to learn the word embeddings.
#         <ul>
#             <li>Advantage: they are based on our IMDB data and therefore tailored to
#                 helping us to predict the sentiment.
#             </li>
#             <li>Disadvantage: the IMDB dataset (and especially the subset that we are using) is probably too
#                 small to learn really powerful
#                 word embeddings.
#             </li>
#         </ul>
#     </li>
#     <li>To some extent, word embeddings are fairly generic, so it can make sense to reuse
#         pretrained embeddings from very large datasets, as we did with image data.
#         <ul>
#             <li><i>word2vec</i> (<a href="https://code.google.com/archive/p/word2vec/">https://code.google.com/archive/p/word2vec/</a>):
#                 This is Google's famous algorithm for learning word embeddings. The URL contains
#                 code and also pretrained embeddings learned from news articles.
#             </li>
#             <li><i>GloVe</i> (Global Vectors for Word Representation,
#                 <a href="https://nlp.stanford.edu/projects/glove/">https://nlp.stanford.edu/projects/glove/</a>):
#                 This is a Stanford University algorithm. The URL has code and pretrained
#                 embeddings learned from Wikipedia.
#             </li>
#         </ul>
#     </li>
#     <li>Although we'll use GloVe, let's briefly explain how Google learns its <i>word2vec</i> word embeddings:
#         <ul>
#             <li>It takes a large body of text (e.g. Wikipedia) and builds a model (a two-layer neural netwoork
#                 classifier) that predicts words.
#             </li>
#             <li>E.g. in what is known as <i>CBOW (continuous bag-of-words)</i>, it predicts the current word from
#                 a window of surrounding words.
#             </li>
#             <li>Or e.g. in what is know as <i>continuous skip-gram</i>, it predicts the surrounding words from
#                 the current word.
#             </li>
#         </ul>
#     </li>
# </ul>

# %% [markdown]
# <h2>IMDB</h2>
# <ul>
#     <li>To run the code that follows, you need to download and unzip the file called
#         <code>glove.6B.zip</code> (&gt;800MB) from the URL above; save space by deleting all files except
#         <code>glove.6B.100d.txt</code> (it's still &gt;300MB)
#     </li>
#     <li>The code comes from Chollet's book &mdash; details are not important in CS4619</li>
# </ul>

# %%
# Parse the GloVe word embeddings file: produces a dictionary from words to their vectors

path = "../datasets/glove.6B.100d.txt" # Edit this to point to your copy of the file

embeddings_index = {}
f = open(path)
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype="float32")
    embeddings_index[word] = coefs
f.close()

# %%
# Create a matrix that associates the words that we obtained from the IMDB reviews earlier 
# (in the word_index) with their GloVe word embeddings

embedding_matrix = np.zeros((vocab_size, embedding_dimension)) 
for word, i in tokenizer.word_index.items():
    if i < vocab_size:
        word_embedding = embeddings_index.get(word)
        if word_embedding is not None:
            embedding_matrix[i] = word_embedding

# %%
# Let's take a look at some of the embeddings
glove_like = embedding_matrix[ tokenizer.word_index["like"] ]
glove_love = embedding_matrix[ tokenizer.word_index["love"] ]
glove_hate = embedding_matrix[ tokenizer.word_index["hate"] ]

print("like: ", glove_like)

# Similarities
print("like and love: ", glove_like.dot(glove_love) )
print("like and hate: ", glove_like.dot(glove_hate) )
# Out:
# like:  [-0.2687      0.81708002  0.69896001 -0.72341001  0.091566    0.19557001
#  -0.52112001 -0.24313    -0.44701001 -0.27039    -0.34125999 -0.46898001
#   0.42583001  0.46289     0.17106    -0.26795     0.23162     0.46568
#  -0.31808001  0.75875002  0.31856999  0.64124     0.067042   -0.18516999
#   0.49996001  0.36963999 -0.31172001 -0.73097998 -0.26901999 -0.32058001
#   0.23394001  0.24276     0.1426     -0.2793      0.38823     0.42398
#   0.1021      0.33316001  0.30149999 -0.52710998 -0.024475   -0.15301
#  -0.3224     -0.51231003 -0.55250001  0.29819     0.10847     0.052334
#  -0.2298     -0.77889001 -0.08928     0.48109001  0.015368    0.92544001
#  -0.26122001 -2.47589993 -0.019825    0.58280998  1.30599999  0.73512
#  -0.34371999  1.58290005 -0.10814     0.11388     0.79220003  0.18347
#   1.22319996  0.35697001  0.17504001 -0.16527    -0.012827   -0.47918001
#  -0.32111001 -0.40573001 -0.37151     0.086323    0.25172001 -0.082751
#  -0.25584    -0.19178     1.0474     -0.51984    -0.71463001  0.38826999
#  -1.67219996  0.015986   -0.22668    -0.26602    -0.57924998 -0.85650998
#   0.20543    -0.46371999 -0.065652   -0.061944   -0.57233    -0.46406001
#  -0.41405001 -0.40110001  0.74656999  0.31121999]
# like and love:  22.626507609439354
# like and hate:  16.022173191630944

# %%
def build_pretrained_word_embedding_network(): 
    network = Sequential()
    network.add(Embedding(input_dim=vocab_size, input_length=maxlen, output_dim=embedding_dimension))
    # Load the pretrained word embeddings into the Embedding layer and freeze them
    network.layers[0].set_weights([embedding_matrix])
    network.layers[0].trainable = False
    network.add(Flatten())
    network.add(Dense(32, activation="relu"))
    network.add(Dense(1, activation="sigmoid"))
    network.compile(optimizer=SGD(lr=0.001), loss="binary_crossentropy", metrics=["acc"])
    return network

# %%
pretrained_word_embedding_network = build_pretrained_word_embedding_network()

# %%
pretrained_word_embedding_history = pretrained_word_embedding_network.fit(rest_of_X, rest_of_y, epochs=10, batch_size=32, validation_split=0.25, 
                                    callbacks=[EarlyStopping(monitor="val_loss", patience=2)], verbose=0)

# %%
pd.DataFrame(pretrained_word_embedding_history.history).plot()
# Out:
# <AxesSubplot:>
